# %% [markdown]
# <a href="https://colab.research.google.com/github/Barryugo/Barryugo/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 12.9 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

stanfordnlp = load_dataset("stanfordnlp/shp")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/stanfordnlp___json/stanfordnlp--shp-a63343e047b69134/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 5.9 MB/s eta 0:00:00
# ...

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 54.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 KB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 6.5 MB/s eta 0:00:00
# ...

# %%
# Step 1: Set up the environment
import openai
import requests # for making HTTP requests
import json # for parsing JSON responses
import gradio as gr # for creating web interface
# Get your OpenAI API key from https://beta.openai.com/account/api-keys
openai.api_key = "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"
# Step 2: Create the FAQ data
faq_data = [
    {
        "question": "What does your company do?",
        "answer": " Our company connects athletes with potential sponsors and promotes college athletes to help them achieve their athletic and financial goals."
    },
    {
        "question": "What is sports?",
        "answer": "Sports are physical activities that involve skill, competition, and entertainment. Some examples of sports are soccer, basketball, tennis, golf, and cricket."
    },
    {
        "question": "Who is the best soccer player in the world?",
        "answer": "This is a subjective question that depends on personal preference and criteria. Some of the most popular and talented soccer players in the world are Lionel Messi, Cristiano Ronaldo, Neymar Jr., Kylian Mbappé, and Robert Lewandowski."
    },
    {
        "question":"How can I become an athlete on your platform?",
        "answer":"To become an athlete on our platform, you can create a profile on our website and provide information about your athletic achievements and goals. We also provide opportunities for college athletes to be promoted by submitting their profiles to our database."
    },
    {
        "question":"How does your platform connect athletes with sponsors?",
        "answer":"Our platform uses an algorithm to match athletes with potential sponsors based on their athletic achievements and interests."
    },
    {
        "question":"What types of sponsorships are available through your platform?",
        "answer":"Our platform offers a range of sponsorship opportunities, including product sponsorships, event sponsorships, and endorsement deals."
    },
    {
        "question":"How does your company help college athletes?",
        "answer":"We help college athletes by promoting them to potential sponsors and providing them with resources to help them navigate the sponsorship process. We also provide tips and advice on how to balance academics and athletics, and how to prepare for a career in sports."
    },
    {
        "question":"What sets your platform apart from other athlete sponsorship companies?",
        "answer":"Our platform is unique in that we not only connect athletes with sponsors, but we also promote college athletes to help them gain exposure and opportunities. We are committed to helping athletes at all levels achieve their goals and succeed both on and off the field."
    }
    # Add more questions and answers here
]
# Step 3: Use the ChatGPT API
def chatgpt(query):
    # Convert the FAQ data into a prompt for ChatGPT
    prompt = ""
    for faq in faq_data:
        prompt += f"Q: {faq['question']}\n"
        prompt += f"A: {faq['answer']}\n\n"
    
    # Add the user query to the prompt
    prompt += f"Q: {query}\n"
    
    # Make a request to ChatGPT API with parameters
    url = "https://api.openai.com/v1/engines/gpt-3.5-turbo/completions"
    params = {
        "prompt": prompt,
        "max_tokens": 100,
        "temperature": 0.9,
        "frequency_penalty": 0.1,
        "presence_penalty": 0.6,
        "stop": "\n\n"
    }
    
    response = requests.post(url=url, params=params)
    print(response.json())
    print(response.status_code)
    # Parse the response and extract the answer
    data = response.json()
    
    answer = data["choices"][0]["text"]
    
    return answer
# Step 4: Build the chatbot
# Create a web interface using Gradio library
interface = gr.Interface(
            fn=chatgpt,
            inputs=gr.inputs.Textbox(lines=2,label="Enter your question here"),
            outputs=gr.outputs.Textbox(label="JRZY's answer"),
            title="JRZY Chatbot",
            description="A simple sports chatbot powered by ChatGPT API for JRZY.",
            examples=[["How many players are there in a soccer team?"], ["Who won the last FIFA World Cup?"],["Who is the best player in the NBA?"]]
)
# Launch the interface locally or on web (requires internet connection)
interface.launch()
# Out:
# /usr/local/lib/python3.8/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.8/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.8/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d081855d-f351-487d-a0f3-68b92af361b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d081855d-f351-487d-a0f3-68b92af361b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'my_data.csv': b',url,text\n0,https://www.jrzy.com/post/how-the-ai-movement-is-changing-sports,"How The AI Movement Is Changing Sports App The Mag NFT\xc2\xa0Cards For Athletes For Brands JRZYverse JRZYapp JRZY JRZYCards JRZYVerse JRZYVersity JRZYCoin Shop Contact Sign up Featured Business News Web3 Sports Tech Athlete Excellence All Content Sports Tech How The AI Movement Is Changing Sports There has been many innovations in sport, but few have had the influence that AI currently has in sports. There has been many innovations in sport, but few have had the influence that AI currently has in sports. Brought to you by Barry Ugochukwu on February 16, 2023 Category: Sports Tech The majority of the improvements in the sport world have been technological. Technology has advanced so much throughout history that most tasks are now simple, quick, and efficient. This is also the same in sports, where cutting-edge technology has transformed sport from a mere source of entertainment to one of 
# ...

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.jrzy.com/post/how-the-ai-movement-...
# 1  https://www.jrzy.com/post/how-can-gpt-3-be-use...
# 2  https://www.jrzy.com/post/looking-beyond-spons...
# 3  https://www.jrzy.com/post/why-do-we-buy-tradin...
# 4  https://www.jrzy.com/post/should-athletes-be-a...
#
#                                                 text
# 0  How The AI Movement Is Changing Sports App The...
# 1  What Is GPT-3 And How Can It Be Useful In Spor...
# 2  Looking beyond sponsorships and endorsements, ...
# 3  Why do we buy trading cards? App The Mag NFT C...
# 4  Should Athletes Be Able To Participate In Spor...

# %%
import re
import nltk

nltk.download('punkt')
nltk.download('stopwords')

def clean_text(text):
    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)  # Remove non-alphanumeric characters
    text = text.lower().strip()  # Lowercase and remove leading/trailing whitespaces
    return text

def filter_text(text):
    stopwords = nltk.corpus.stopwords.words('english')
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(filtered_tokens)



data['clean_text'] = [clean_text(text) for text in data['text']]
data['filtered_text'] = [filter_text(text) for text in data['clean_text']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.jrzy.com/post/how-the-ai-movement-...
# 1  https://www.jrzy.com/post/how-can-gpt-3-be-use...
# 2  https://www.jrzy.com/post/looking-beyond-spons...
# 3  https://www.jrzy.com/post/why-do-we-buy-tradin...
# 4  https://www.jrzy.com/post/should-athletes-be-a...
#
#                                                 text  \
# 0  How The AI Movement Is Changing Sports App The...
# 1  What Is GPT-3 And How Can It Be Useful In Spor...
# 2  Looking beyond sponsorships and endorsements, ...
# 3  Why do we buy trading cards? App The Mag NFT C...
# 4  Should Athletes Be Able To Participate In Spor...
#
#                                           clean_text  \
# 0  how the ai movement is changing sports app the...
# 1  what is gpt 3 and how can it be useful in spor...
# 2  looking beyond sponsorships and endorsements  ...
# 3  why do we buy trading cards  app the mag nft c...
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 99.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 129.3 MB/s eta 0:00:00
# ...

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained('gpt2')
model.resize_token_embeddings(len(tokenizer))

train_texts = data['filtered_text'].tolist()
train_encodings = tokenizer(train_texts, truncation=True, padding=True)

train_dataset = {'input_ids': train_encodings['input_ids'], 'attention_mask': train_encodings['attention_mask']}

training_args = TrainingArguments(
    output_dir='./results',
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=8,
    save_total_limit=2,
    logging_steps=100,
    eval_steps=500,
    save_steps=1000,
    prediction_loss_only=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False),
    
)

trainer.train()
# Out:
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/e7da7f221d5bf496a48136c0cd264e630fe9fcc8/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/e7da7f221d5bf496a48136c0cd264e630fe9fcc8/merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/e7da7f221d5bf496a48136c0cd264e630fe9fcc8/config.json
# Model config GPT2Config {
#   "_name_or_path": "gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
# ...

# %%
train_texts

# %%
def generate_text(prompt, model, tokenizer):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    attention_mask = torch.ones(input_ids.shape, dtype=torch.long, device=model.device)
    output = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=1024, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
    return tokenizer.decode(output[0])

# %%
generated_text = generate_text("Whhat is NIL?", model, tokenizer)
print(generated_text)
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Whhat is NIL?
#
# ...

# %%
generated_text = generate_text("Is sports betting bad?", model, tokenizer)
print(generated_text)
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Is sports betting bad?
#
# It's hard to know what to make of this story, but I think it's a good one. I don't think there's anything wrong with betting on sports. It's just that there are a lot of people out there who want to bet on it, and they're not going to be able to do it for free. That's not the case here. There are people who are willing to pay a little bit of money for a chance to see what they think is going on in the world. And that's what we're doing. We're trying to get people to come to the table and say, "Hey, this is what you're looking for. This is how you want it to go." And then we try to figure out how we can make it work for them. So we've been doing that for some time now. But I'm not sure if we'll ever get there.<|endoftext|>
